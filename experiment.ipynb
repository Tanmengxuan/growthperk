# %%
with open('outputfile-BDM_NY.txt') as f:
    content = f.readlines()

print (content)
# Out:
# ['https://www.linkedin.com/jobs/business-development-jobs-new-york\n', 'https://www.linkedin.com/in/shaun-sefker-69675799\n', 'https://uk.linkedin.com/in/rory-kirwan-b8401939\n', 'https://www.linkedin.com/jobs/search/?f_TP=1&amp;location=New%20York%2C%20New%20York&amp;locationId=PLACES.us.3-2-0-31-1\n', 'https://www.linkedin.com/in/silkeschroeder\n', 'https://www.linkedin.com/in/sara-benton-15366547\n', 'https://www.linkedin.com/in/marc-j-lee\n', 'https://www.linkedin.com/salary/explorer?countryCode=us&amp;titleId=42\n', 'https://www.linkedin.com/in/shaylamartin\n', 'https://www.linkedin.com/in/jonesnicolette\n', 'https://www.linkedin.com/in/aaron-dektor-93433250\n', 'https://www.linkedin.com/salary/business-development-salaries-in-greater-new-york-city-area\n', 'https://www.linkedin.com/in/vineetbokaria\n', 'https://www.linkedin.com/jobs/latin-america-business-development-jobs\n', 'https://www.linkedin.com/jobs/sales-business-development-manager-jobs\n', 'https://www.linkedin.com/in
# ...

# %%
for i in content:
    print (i)
# Out:
# https://www.linkedin.com/jobs/business-development-jobs-new-york
#
# https://www.linkedin.com/in/shaun-sefker-69675799
#
# https://uk.linkedin.com/in/rory-kirwan-b8401939
#
# https://www.linkedin.com/jobs/search/?f_TP=1&amp;location=New%20York%2C%20New%20York&amp;locationId=PLACES.us.3-2-0-31-1
#
# https://www.linkedin.com/in/silkeschroeder
#
# https://www.linkedin.com/in/sara-benton-15366547
#
# https://www.linkedin.com/in/marc-j-lee
#
# https://www.linkedin.com/salary/explorer?countryCode=us&amp;titleId=42
#
# https://www.linkedin.com/in/shaylamartin
#
# https://www.linkedin.com/in/jonesnicolette
#
# https://www.linkedin.com/in/aaron-dektor-93433250
#
# https://www.linkedin.com/salary/business-development-salaries-in-greater-new-york-city-area
#
# https://www.linkedin.com/in/vineetbokaria
#
# https://www.linkedin.com/jobs/latin-america-business-development-jobs
#
# https://www.linkedin.com/jobs/sales-business-development-manager-jobs
#
# ...
